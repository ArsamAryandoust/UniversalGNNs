# %% [markdown]
# # Preparing Uber Movement travel time data
#
# Overview
# 1. Inspect raw data
# 2. Process raw data
#
# ---
#
# We start with importing hyper parameters and modules

# %%
import hyper
import prep_uber_movement
import pandas as pd

HYPER = hyper.HyperParameter()

# %% [markdown]
# ### 1. Inspect raw data
# Let us first inspect the available raw data files for an exemplar city. This will allow us to better understand our raw data and what our features and labels are. We have data available for and can choose from the following list of cities:
#
# Amsterdam, Atlanta, Auckland, Bagalore, Bogota, Boston, Brisbane, Bristol, Brussels, Cairo, Cape Town, Cincinnati, Guadalajara, Hyderabad, Johannesburg and Pretoria, Kolkata, Leeds, London, Los Angeles, Madrid, Manchester, Melbourne, Mexico City, Miami, Mumbai, Nairobi, New Delhi, Orlando, Paris, Perth, Pittsburgh, San Francisco, Santiago De Chile, Sao Paulo, Seattle, Stockholm, Sydney, Taipei, Tampa Bay, Toronto, Vienna, 'Washington D.C.', 'West Midlands, UK'.
#
# The raw data shows a number of characteristics that are worth to note:
#
# * Travel time data is describes by four distinct values: mean, std, gemoetric mean and geometric std. These are our labels
# * Our features are hour of day, a source ID and a destination ID. We can further see that the filename of our .csv files contain further meta data that is useful for describining features, which are the year, the quarter of the year and the day type (weekday or weekend).
# * The geojson file further maps a set of latitudinal and longitudinal coordinates to each city zone ID, which describe the coordinates of a two dimensional polygon representing each zone.

# %%
# choose a city from the list of available ones above
city = 'Santiago De Chile'

# call the import data function
df_csv_dict_list, df_geojson = prep_uber_movement.import_data(HYPER, city)
df_csv_dict = df_csv_dict_list[0]
df_csv = df_csv_dict['df']

# set maximum column width to see more of geojson
pd.set_option('max_colwidth', 400)

# print filename
print(df_csv_dict['filename'])
display(df_csv)
display(df_geojson)
# Out:
# santiago-tazs-2020-1-OnlyWeekends-HourlyAggregate.csv
#          sourceid  dstid  hod  mean_travel_time  \
# 0             364    523   10            463.21
# 1             360    563   10            422.82
# 2             411     39   11           1123.33
# 3             412     29   11            847.92
# 4             384    323   10            718.39
# ...           ...    ...  ...               ...
# 4740940       705    750   14           1087.76
# 4740941       364    481   12           1181.83
# 4740942        31    155    7            702.46
# 4740943        32    145    7            943.33
# 4740944       712    680   14            641.22
#
#          standard_deviation_travel_time  geometric_mean_travel_time  \
# 0                                106.06                      450.49
# 1                                263.68                      378.38
# 2                                237.19                     1099.77
# 3                                360.00                      796.87
# 4                                194.36                      695.59
# ...                                 ...                         ...
# 4740940                          194.36                     1071.25
# 4740941                          280.74                     1149.64
# 4740942                          251.17                      648.58
# 4740943                          156.35                      929.80
# 4740944                          289.26                      582.12
#
#          geometric_standard_deviation_travel_time
# 0                                            1.27
# 1                                            1.52
# 2                                            1.23
# 3                                            1.38
# 4                                            1.28
# ...                                           ...
# 4740940                                      1.19
# 4740941                                      1.26
# 4740942                                      1.59
# 4740943                                      1.19
# 4740944                                      1.56
#
# [4740945 rows x 7 columns]
#                   type  \
# 0    FeatureCollection
# 1    FeatureCollection
# 2    FeatureCollection
# 3    FeatureCollection
# 4    FeatureCollection
# ..                 ...
# 861  FeatureCollection
# 862  FeatureCollection
# 863  FeatureCollection
# 864  FeatureCollection
# 865  FeatureCollection
#
#                                                                                                                                                                                                                                                                                                                                                                                                             features
# 0    {'type': 'Feature', 'properties': {'ID': 318, 'Com': '13114', 'Comuna': 'Las Condes', 'Zona': 0, 'MOVEMENT_ID': '1', 'DISPLAY_NAME': 'ID 318'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.502431, -33.413271], [-70.501605, -33.411482], [-70.498702, -33.40983], [-70.497354, -33.406758], [-70.497221, -33.406457], [-70.497104, -33.406215], [-70.496966, -33.405883], [-70.496874, -33.40560...
# 1    {'type': 'Feature', 'properties': {'ID': 311, 'Com': '13114', 'Comuna': 'Las Condes', 'Zona': 0, 'MOVEMENT_ID': '2', 'DISPLAY_NAME': 'ID 311'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.481813, -33.381629], [-70.482387, -33.381501], [-70.482879, -33.381256], [-70.483069, -33.380947], [-70.484274, -33.38068], [-70.484722, -33.380363], [-70.4853, -33.38005], [-70.485688, -33.379973],...
# 2    {'type': 'Feature', 'properties': {'ID': 301, 'Com': '13114', 'Comuna': 'Las Condes', 'Zona': 0, 'MOVEMENT_ID': '3', 'DISPLAY_NAME': 'ID 301'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.50838, -33.382148], [-70.508312, -33.382176], [-70.507478, -33.382515], [-70.506985, -33.382846], [-70.506507, -33.383235], [-70.506331, -33.383444], [-70.505974, -33.383927], [-70.505499, -33.38438...
# 3    {'type': 'Feature', 'properties': {'ID': 734, 'Com': '13301', 'Comuna': 'Colina', 'Zona': 0, 'MOVEMENT_ID': '4', 'DISPLAY_NAME': 'ID 734'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.696061, -33.23737], [-70.695396, -33.237609], [-70.69443, -33.238659], [-70.694308, -33.240361], [-70.694167, -33.241323], [-70.69352, -33.242072], [-70.69245599999999, -33.242429], [-70.680991, -33.243...
# 4    {'type': 'Feature', 'properties': {'ID': 330, 'Com': '13115', 'Comuna': 'Lo Barnechea', 'Zona': 0, 'MOVEMENT_ID': '5', 'DISPLAY_NAME': 'ID 330'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.508914, -33.36313], [-70.508523, -33.362549], [-70.509173, -33.360728], [-70.509875, -33.35865], [-70.509982, -33.358189], [-70.510056, -33.358125], [-70.510121, -33.357844], [-70.510203, -33.3575...
# ..                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 861  {'type': 'Feature', 'properties': {'ID': 116, 'Com': '13105', 'Comuna': 'El Bosque', 'Zona': 0, 'MOVEMENT_ID': '862', 'DISPLAY_NAME': 'ID 116'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.668194, -33.552065999999996], [-70.667008, -33.552307], [-70.665641, -33.552596], [-70.663092, -33.553018], [-70.659782, -33.553559], [-70.660577, -33.556952], [-70.660536, -33.557012], [-70.661456...
# 862  {'type': 'Feature', 'properties': {'ID': 115, 'Com': '13105', 'Comuna': 'El Bosque', 'Zona': 0, 'MOVEMENT_ID': '863', 'DISPLAY_NAME': 'ID 115'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.675992, -33.555423], [-70.676018, -33.555247], [-70.676245, -33.555131], [-70.676525, -33.555069], [-70.677081, -33.554953], [-70.679131, -33.554524], [-70.684753, -33.553393], [-70.683691, -33.551...
# 863  {'type': 'Feature', 'properties': {'ID': 106, 'Com': '13105', 'Comuna': 'El Bosque', 'Zona': 0, 'MOVEMENT_ID': '864', 'DISPLAY_NAME': 'ID 106'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.675992, -33.555423], [-70.677667, -33.557529], [-70.678909, -33.559108], [-70.680191, -33.560773], [-70.681701, -33.562642], [-70.685514, -33.567351], [-70.686456, -33.568551], [-70.687069, -33.569...
# 864  {'type': 'Feature', 'properties': {'ID': 104, 'Com': '13105', 'Comuna': 'El Bosque', 'Zona': 0, 'MOVEMENT_ID': '865', 'DISPLAY_NAME': 'ID 104'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.678909, -33.559108], [-70.677667, -33.557529], [-70.675992, -33.555423], [-70.674523, -33.55355], [-70.67263, -33.551122], [-70.67106, -33.549141], [-70.669547, -33.547205], [-70.668189, -33.545519...
# 865  {'type': 'Feature', 'properties': {'ID': 103, 'Com': '13105', 'Comuna': 'El Bosque', 'Zona': 0, 'MOVEMENT_ID': '866', 'DISPLAY_NAME': 'ID 103'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.654847, -33.554364], [-70.654967, -33.554931], [-70.654918, -33.554995], [-70.655168, -33.555857], [-70.655397, -33.556801], [-70.655828, -33.558193], [-70.656834, -33.562431], [-70.656986, -33.562...
#
# [866 rows x 2 columns]

# %% [markdown]
# ### 2. Process raw data
#
# The data is already clean. The only part that must be processed are the geojson coordinates describing each city zone polygon with latitudes and longitudes. We write a recursive function that fosters the json files and extracts only the latitude and longitude coordinates mapped to each city zone ID.
#
# The format of files resulting from this step are shown below.

# %%
map_movement_id_to_coordinates = prep_uber_movement.process_geojson(df_geojson)
latitudes = map_movement_id_to_coordinates[0]
longitudes = map_movement_id_to_coordinates[1]

df_latitudes = pd.DataFrame.from_dict(latitudes, orient='index').transpose()
df_longitudes = pd.DataFrame.from_dict(longitudes, orient='index').transpose()

display(df_latitudes)
display(df_longitudes)
# Out:
#            1          2          3          4          5          6    \
# 0   -33.413271 -33.381629 -33.382148 -33.237370 -33.363130 -33.324829
# 1   -33.411482 -33.381501 -33.382176 -33.237609 -33.362549 -33.332767
# 2   -33.409830 -33.381256 -33.382515 -33.238659 -33.360728 -33.335196
# 3   -33.406758 -33.380947 -33.382846 -33.240361 -33.358650 -33.336900
# 4   -33.406457 -33.380680 -33.383235 -33.241323 -33.358189 -33.337482
# ..         ...        ...        ...        ...        ...        ...
# 344        NaN        NaN        NaN        NaN        NaN        NaN
# 345        NaN        NaN        NaN        NaN        NaN        NaN
# 346        NaN        NaN        NaN        NaN        NaN        NaN
# 347        NaN        NaN        NaN        NaN        NaN        NaN
# 348        NaN        NaN        NaN        NaN        NaN        NaN
#
#            7          8          9          10   ...        857        858  \
# 0   -33.325472 -33.251488 -33.207584 -33.180751  ... -33.556529 -33.561790
# 1   -33.318158 -33.250846 -33.205678 -33.181894  ... -33.556582 -33.561790
# 2   -33.316544 -33.249816 -33.204387 -33.183403  ... -33.557187 -33.561874
# 3   -33.318717 -33.248468 -33.203974 -33.185337  ... -33.557241 -33.561958
# 4   -33.345531 -33.246615 -33.203897 -33.186151  ... -33.559627 -33.562042
# ..         ...        ...        ...        ...  ...        ...        ...
# 344        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 345        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 346        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 347        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 348        NaN        NaN        NaN        NaN  ...        NaN        NaN
#
#            859        860        861        862        863        864  \
# 0   -33.550502 -33.556417 -33.558483 -33.552066 -33.555423 -33.555423
# 1   -33.550489 -33.556508 -33.558590 -33.552307 -33.555247 -33.557529
# 2   -33.550496 -33.556548 -33.558772 -33.552596 -33.555131 -33.559108
# 3   -33.550503 -33.556582 -33.558936 -33.553018 -33.555069 -33.560773
# 4   -33.550524 -33.556723 -33.559630 -33.553559 -33.554953 -33.562642
# ..         ...        ...        ...        ...        ...        ...
# 344        NaN        NaN        NaN        NaN        NaN        NaN
# 345        NaN        NaN        NaN        NaN        NaN        NaN
# 346        NaN        NaN        NaN        NaN        NaN        NaN
# 347        NaN        NaN        NaN        NaN        NaN        NaN
# 348        NaN        NaN        NaN        NaN        NaN        NaN
#
#            865        866
# 0   -33.559108 -33.554364
# 1   -33.557529 -33.554931
# 2   -33.555423 -33.554995
# 3   -33.553550 -33.555857
# 4   -33.551122 -33.556801
# ..         ...        ...
# 344        NaN        NaN
# 345        NaN        NaN
# 346        NaN        NaN
# 347        NaN        NaN
# 348        NaN        NaN
#
# [349 rows x 866 columns]
#            1          2          3          4          5          6    \
# 0   -70.502431 -70.481813 -70.508380 -70.696061 -70.508914 -70.499148
# 1   -70.501605 -70.482387 -70.508312 -70.695396 -70.508523 -70.488909
# 2   -70.498702 -70.482879 -70.507478 -70.694430 -70.509173 -70.483799
# 3   -70.497354 -70.483069 -70.506985 -70.694308 -70.509875 -70.482651
# 4   -70.497221 -70.484274 -70.506507 -70.694167 -70.509982 -70.483064
# ..         ...        ...        ...        ...        ...        ...
# 344        NaN        NaN        NaN        NaN        NaN        NaN
# 345        NaN        NaN        NaN        NaN        NaN        NaN
# 346        NaN        NaN        NaN        NaN        NaN        NaN
# 347        NaN        NaN        NaN        NaN        NaN        NaN
# 348        NaN        NaN        NaN        NaN        NaN        NaN
#
#            7          8          9          10   ...        857        858  \
# 0   -70.450683 -70.717409 -70.684300 -70.645738  ... -70.585965 -70.595492
# 1   -70.379501 -70.716570 -70.683521 -70.645922  ... -70.586034 -70.595493
# 2   -70.320754 -70.715085 -70.682943 -70.646068  ... -70.585932 -70.596320
# 3   -70.280546 -70.713078 -70.682457 -70.646060  ... -70.585999 -70.597135
# 4   -70.277062 -70.710174 -70.681820 -70.646237  ... -70.585576 -70.597985
# ..         ...        ...        ...        ...  ...        ...        ...
# 344        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 345        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 346        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 347        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 348        NaN        NaN        NaN        NaN  ...        NaN        NaN
#
#            859        860        861        862        863        864  \
# 0   -70.613742 -70.561028 -70.575938 -70.668194 -70.675992 -70.675992
# 1   -70.613670 -70.560980 -70.576761 -70.667008 -70.676018 -70.677667
# 2   -70.613134 -70.561028 -70.578352 -70.665641 -70.676245 -70.678909
# 3   -70.612582 -70.561179 -70.579654 -70.663092 -70.676525 -70.680191
# 4   -70.612048 -70.562175 -70.585364 -70.659782 -70.677081 -70.681701
# ..         ...        ...        ...        ...        ...        ...
# 344        NaN        NaN        NaN        NaN        NaN        NaN
# 345        NaN        NaN        NaN        NaN        NaN        NaN
# 346        NaN        NaN        NaN        NaN        NaN        NaN
# 347        NaN        NaN        NaN        NaN        NaN        NaN
# 348        NaN        NaN        NaN        NaN        NaN        NaN
#
#            865        866
# 0   -70.678909 -70.654847
# 1   -70.677667 -70.654967
# 2   -70.675992 -70.654918
# 3   -70.674523 -70.655168
# 4   -70.672630 -70.655397
# ..         ...        ...
# 344        NaN        NaN
# 345        NaN        NaN
# 346        NaN        NaN
# 347        NaN        NaN
# 348        NaN        NaN
#
# [349 rows x 866 columns]
