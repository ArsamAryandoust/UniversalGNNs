# %% [markdown]
# # Preparing Uber Movement travel time data into graph
#
# This is what we do here

# %%
import hyper

HYPER = hyper.HyperParameter()

# %%
HYPER.UBERMOVEMENT_CITY_FILES_MAPPING
# Out:
# {'Guadalajara': {'json': 'guadalajara_agebs.json',
#   'weekdays': 'guadalajara-agebs-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'guadalajara-agebs-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Stockholm': {'json': 'stockholm_basomrade.json',
#   'weekdays': 'stockholm-basomrade-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'stockholm-basomrade-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'San Francisco': {'json': 'san_francisco_censustracts.json',
#   'weekdays': 'san_francisco-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'san_francisco-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Perth': {'json': 'perth_cityzones.json',
#   'weekdays': 'perth-cityzones-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'perth-cityzones-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Auckland': {'json': 'auckland_statistical_area.json',
#   'weekdays': 'auckland-statistical_area-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'auckland-statistical_area-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Boston': {'json': 'boston_censustracts.json',
#   'weekdays': 'boston-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'boston-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Brussels': {'json': 'brussels_statisticaldistrict.json',
#   'weekdays': 'brussels-statisticaldistrict-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'brussels-statisticaldistrict-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'London': {'json': 'london_lsoa.json',
#   'weekdays': 'london-lsoa-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'london-lsoa-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Miami': {'json': 'miami_censustracts.json',
#   'weekdays': 'miami-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'miami-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Leeds': {'json': 'leeds_msoa.json',
#   'weekdays': 'leeds-msoa-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'leeds-msoa-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Tampa Bay': {'json': 'tampa_censustracts.json',
#   'weekdays': 'tampa-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'tampa-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Hyderabad': {'json': 'hyderabad_wards.json',
#   'weekdays': 'hyderabad-wards-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'hyderabad-wards-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Sao Paulo': {'json': 'sao_paulo_od_zones_2017.json',
#   'weekdays': 'sao_paulo-od_zones_2017-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'sao_paulo-od_zones_2017-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Seattle': {'json': 'seattle_censustracts.json',
#   'weekdays': 'seattle-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'seattle-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Bangalore': {'json': 'bangalore_wards.json',
#   'weekdays': 'bangalore-wards-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'bangalore-wards-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Bogota': {'json': 'bogota_cadastral.json',
#   'weekdays': 'bogota-cadastral-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'bogota-cadastral-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'New Delhi': {'json': 'new_delhi_wards.json',
#   'weekdays': 'new_delhi-wards-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'new_delhi-wards-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Vienna': {'json': 'vienna_statistical_areas.json',
#   'weekdays': 'vienna-statistical_areas-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'vienna-statistical_areas-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Cairo': {'json': 'cairo_uberboundaries.json',
#   'weekdays': 'cairo-uberboundaries-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'cairo-uberboundaries-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Sydney': {'json': 'sydney_tz.json',
#   'weekdays': 'sydney-tz-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'sydney-tz-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Nairobi': {'json': 'nairobi_hexclusters.json',
#   'weekdays': 'nairobi-hexclusters-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'nairobi-hexclusters-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Los Angeles': {'json': 'los_angeles_censustracts.json',
#   'weekdays': 'los_angeles-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'los_angeles-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Atlanta': {'json': 'atlanta_censustracts.json',
#   'weekdays': 'atlanta-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'atlanta-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Cincinnati': {'json': 'cincinnati_censustracts.json',
#   'weekdays': 'cincinnati-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'cincinnati-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Johannesburg and Pretoria': {'json': 'johannesburg_gpzones.json',
#   'weekdays': 'johannesburg-gpzones-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'johannesburg-gpzones-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Paris': {'json': 'paris_iris.json',
#   'weekdays': 'paris-iris-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'paris-iris-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Brisbane': {'json': 'brisbane_tz.json',
#   'weekdays': 'brisbane-tz-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'brisbane-tz-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Madrid': {'json': 'madrid_codigos_postales.json',
#   'weekdays': 'madrid-codigos_postales-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'madrid-codigos_postales-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Bristol': {'json': 'bristol_msoa.json',
#   'weekdays': 'bristol-msoa-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'bristol-msoa-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Toronto': {'json': 'toronto_neighbourhoods.json',
#   'weekdays': 'toronto-neighbourhoods-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'toronto-neighbourhoods-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Cape Town': {'json': 'cape_town_travel_zones.json',
#   'weekdays': 'cape_town-travel_zones-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'cape_town-travel_zones-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'West Midlands, UK': {'json': 'west_midlands_msoa.json',
#   'weekdays': 'west_midlands-msoa-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'west_midlands-msoa-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Washington D.C.': {'json': 'washington_DC_censustracts.json',
#   'weekdays': 'washington_DC-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'washington_DC-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Mumbai': {'json': 'mumbai_hexclusters.json',
#   'weekdays': 'mumbai-hexclusters-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'mumbai-hexclusters-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Melbourne': {'json': 'melbourne_tz.json',
#   'weekdays': 'melbourne-tz-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'melbourne-tz-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Pittsburgh': {'json': 'pittsburgh_censustracts.json',
#   'weekdays': 'pittsburgh-censustracts-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'pittsburgh-censustracts-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Santiago De Chile': {'json': 'santiago_tazs.json',
#   'weekdays': 'santiago-tazs-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'santiago-tazs-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Kolkata': {'json': 'kolkata_wards.json',
#   'weekdays': 'kolkata-wards-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'kolkata-wards-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Amsterdam': {'json': 'amsterdam_wijk.json',
#   'weekdays': 'amsterdam-wijk-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'amsterdam-wijk-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Orlando': {'json': 'orlando_tazs.json',
#   'weekdays': 'orlando-tazs-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'orlando-tazs-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Manchester': {'json': 'manchester_msoa.json',
#   'weekdays': 'manchester-msoa-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'manchester-msoa-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Taipei': {'json': 'taipei_taz.json',
#   'weekdays': 'taipei-taz-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'taipei-taz-2020-1-OnlyWeekends-HourlyAggregate.csv'},
#  'Mexico City': {'json': 'mexico_city_agebs.json',
#   'weekdays': 'taipei-taz-2020-1-OnlyWeekdays-HourlyAggregate.csv',
#   'weekends': 'mexico_city-agebs-2020-1-OnlyWeekends-HourlyAggregate.csv'}}
